# %% [markdown]
# # gitfile 메카니즘

# %% [markdown]
# - 레포지토리 정보는 워크트리 최상위 디렉토리 내부의 .git 디렉토리에 저장되는 것이 일반적이지만
# - .git 디렉토리 대신 .git 이라는 이름의 파일을 두고 그 안에 레포지토리 정보가 저장된 다른 디렉토리의 경로를 지정할 수도 있다.
# - 이를 gitfile 메카니즘이라고 한다.
