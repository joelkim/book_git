# %%
# %load_ext jupyter_tikz

# %%
preamble = r"""
\usepackage{kotex}
\usepackage{tikz}
\setmainhangulfont{Noto Sans KR}
"""

# %%
# %%tikz -tp=xelatex -p "$preamble" -S fig_basic_01.svg
# \begin{tikzpicture}
#   \begin{scope}[every node/.style=draw, minimum width=4cm, minimum height=3cm]
#   \node (worktree)         at (0,1) {};
#   \node (stage)            at (5,1) {};
#   \node (repository)       at (10,1) {};
#   \end{scope}
#   \node (worktree-label)   at (0,4) {워크트리};
#   \node (stage-label)      at (5,4) {스테이지};
#   \node (repository-label) at (10,4) {레포지토리};
# \end{tikzpicture}
