# %%
# | echo: false
# | output: false
export LANG=en_US.UTF-8
export HOME=/Users/joelkim/Work/personal/book_git
cd $HOME

# %% [markdown]
# # 머지

# %% [markdown]
# ::: {.hidden}
#
# ## 참고 문헌
#
# - Building Git, Ch. 17 Basic Merging
#   - chrome-extension://oemmndcbldboiebfnladdacbdfmadadm/file:///Users/joelkim/Work/study/study_cs/book/DevOps/Coglan/2021%20-%20Coglan%20-%20Buliding%20Git.pdf
#
# :::

# %% [markdown]
# ## 머지란

# %% [markdown]
# - 두 개의 브랜치를 하나로 합치는 것(병합)

# %% [markdown]
# ## merge 명령

# %% [markdown]
# - merge 명령은 방향성을 가짐
#   - 현재 브랜치(브랜치 A)에서 브랜치 B를 머지하면
#   - 브랜치 A에는 브랜치 B의 내용이 반영된 새로운 커밋이 생성
#   - 브랜치 B는 변화없음

# %% [markdown]
# ### merge 명령 사용법

# %% [markdown]
# - `git merge <머지할 브랜치>`: <머지할 브랜치>를 현재 브랜치에 병합

# %% [markdown]
# ### merge 명령의 옵션

# %% [markdown]
# ## 머지시의 파일 변화

# %% [markdown]
# - 양쪽 브랜치 중 하나에서만 수정이 발생한 경우, 수정 파일을 유지
# - 양쪽 브랜치에서 모두 수정이 발생한 경우, 파일을 비교하여
#   - 같은 위치가 아닌 수정은 양쪽 모두 반영
#   - 같은 위치의 수정이 있는 경우 해당 부분에 대해 충돌

# %% [markdown]
# | 브랜치 A | 브랜치 B | 머지 결과 |
# |-|-|--------|
# | 수정없음 | 수정없음 | 그대로 유지 |
# | 수정     | 수정없음 | 브랜치 A의 수정 반영 |
# | 수정없음 | 수정     | 브랜치 B의 수정 반영 |
# | 수정     | 수정     | 수정 내역에 따라 두 가지 수정이 모두 반영되거나 충돌 |

# %% [markdown]
# - 충돌의 세부적인 내용과 해결 방법은 다음 절에서 설명

# %% [markdown]
# ## 실습 1: 파일의 신규 생성이나 삭제가 없는 경우

# %% [markdown]
# - 레포지토리 생성

# %%
# | output: false
cd $HOME/lab
rm -rf test_merge_01
git init test_merge_01
cd test_merge_01
# Out:
# Initialized empty Git repository in /Users/joelkim/Work/personal/book_git/lab/test_merge_01/.git/

# %% [markdown]
# :::{.cell}
# ::::{.cell-output .cell-output-stdout}
# Initialized empty Git repository in ~/lab/test_merge_01/.git/
# ::::
# :::

# %% [markdown]
# - 3개의 파일 생성

# %%
echo "file1 line 1" > file1.txt
echo "file2 line 1" > file2.txt
echo "file3 line 1" > file3.txt
git add .
git commit -m "c1"
# Out:
# [main (root-commit) 6ffb8f1] c1
#  3 files changed, 3 insertions(+)
#  create mode 100644 file1.txt
#  create mode 100644 file2.txt
#  create mode 100644 file3.txt

# %% [markdown]
# - branch A 생성

# %%
git branch A

# %% [markdown]
# - 브랜치 A로 전환

# %%
git switch A
# Out:
# Switched to branch 'A'

# %% [markdown]
# - file2.txt 수정

# %%
echo "file2 line 1 modified" > file2.txt
git add .
git commit -m "c2"
# Out:
# [A d65f994] c2
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %% [markdown]
# - main 브랜치로 전환

# %%
git switch main
# Out:
# Switched to branch 'main'

# %% [markdown]
# - file3.txt 수정

# %%
echo "file3 line 1 modified" > file3.txt
git add .
git commit -m "c3"
# Out:
# [main b6e62b1] c3
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %% [markdown]
# - 현재 브랜치 상태

# %%
git log --oneline --graph --all --decorate
# Out:
# * d65f994 (A) c2
# | * b6e62b1 (HEAD -> main) c3
# |/
# * 6ffb8f1 c1

# %% [markdown]
# - main 브랜치에서 A 브랜치 머지

# %%
git merge A -m "c4"
# Out:
# Merge made by the 'ort' strategy.
#  file2.txt | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %% [markdown]
# - main 브랜치에는 c4 라는 머지 커밋이 생성
# - A 브랜치는 그대로 변화없음

# %%
git log --oneline --graph --all --decorate
# Out:
# *   8273964 (HEAD -> main) c4
# |\
# | * d65f994 (A) c2
# * | b6e62b1 c3
# |/
# * 6ffb8f1 c1

# %% [markdown]
# - 머지 결과 아무데서도 수정하지 않은 것은 그대로 유지

# %%
cat file1.txt
# Out:
# file1 line 1

# %% [markdown]
# - A 브랜치에서만 수정한 경우 수정한 파일이 남음

# %%
cat file2.txt
# Out:
# file2 line 1 modified

# %% [markdown]
# - main 브랜치에서만 수정한 경우 수정한 파일이 남음

# %%
cat file3.txt
# Out:
# file3 line 1 modified

# %% [markdown]
# ## 파일이 신규로 생성되는 경우

# %% [markdown]
# - 양쪽 브랜치 중 하나에서만 신규 파일이 생성된 경우, 신규 파일을 반입
# - 양쪽 브랜치에서 모두 신규 파일이 생성된 경우, 파일을 비교하여
#   - 같은 위치가 아닌 내역은 양쪽 모두 반영
#   - 같은 위치의 내역은 경우 해당 부분에 대해 충돌

# %% [markdown]
# | 브랜치 A  | 브랜치 B | 머지 결과 |
# |-|-|--------|
# | 신규 생성 | 생성 없음 | 신규 파일 반입 |
# | 생성 없음 | 신규 생성 | 신규 파일 반입 |
# | 신규 생성 | 신규 생성 | 파일 내용에 따라 두 파일이 모두 반영되거나 충돌 |

# %% [markdown]
# ## 실습 2: 파일이 신규 생성되는 경우

# %% [markdown]
# - 레포지토리 생성

# %%
# | output: false
cd $HOME/lab
rm -rf test_merge_02
git init test_merge_02
cd test_merge_02
# Out:
# Initialized empty Git repository in /Users/joelkim/Work/personal/book_git/lab/test_merge_02/.git/

# %% [markdown]
# :::{.cell}
# ::::{.cell-output .cell-output-stdout}
# Initialized empty Git repository in ~/lab/test_merge_02/.git/
# ::::
# :::

# %% [markdown]
# - 1개의 파일 생성

# %%
echo "file1 line 1" > file1.txt
git add .
git commit -m "c1"
# Out:
# [main (root-commit) 568caf2] c1
#  1 file changed, 1 insertion(+)
#  create mode 100644 file1.txt

# %% [markdown]
# - branch A 생성

# %%
git branch A

# %% [markdown]
# - 브랜치 A로 전환

# %%
git switch A
# Out:
# Switched to branch 'A'

# %% [markdown]
# - file2.txt 생성

# %%
echo "file2 line 1" > file2.txt
git add .
git commit -m "c2"
# Out:
# [A f844307] c2
#  1 file changed, 1 insertion(+)
#  create mode 100644 file2.txt

# %% [markdown]
# - main 브랜치로 전환

# %%
git switch main
# Out:
# Switched to branch 'main'

# %% [markdown]
# - file3.txt 생성

# %%
echo "file3 line 1" > file3.txt
git add .
git commit -m "c3"
# Out:
# [main 03e84d7] c3
#  1 file changed, 1 insertion(+)
#  create mode 100644 file3.txt

# %% [markdown]
# - 현재 브랜치 상태

# %%
git log --oneline --graph --all --decorate
# Out:
# * 03e84d7 (HEAD -> main) c3
# | * f844307 (A) c2
# |/
# * 568caf2 c1

# %% [markdown]
# - main 브랜치에서 A 브랜치 머지

# %%
git merge A -m "c4"
# Out:
# Merge made by the 'ort' strategy.
#  file2.txt | 1 +
#  1 file changed, 1 insertion(+)
#  create mode 100644 file2.txt

# %% [markdown]
# - main 브랜치에는 c4 라는 머지 커밋이 생성
# - A 브랜치는 그대로 변화없음

# %%
git log --oneline --graph --all --decorate
# Out:
# *   85cfcc6 (HEAD -> main) c4
# |\
# | * f844307 (A) c2
# * | 03e84d7 c3
# |/
# * 568caf2 c1

# %% [markdown]
# - 양쪽 브랜치에서 새로 만든 파일들이 모두 포함됨

# %%
ls
# Out:
# file1.txt	file2.txt	file3.txt

# %% [markdown]
# ## 파일이 삭제되는 경우

# %% [markdown]
# - 양쪽 브랜치 중 어디든 한 쪽에서 파일이 삭제되면 모두 제거됨

# %% [markdown]
# | 브랜치 A  | 브랜치 B | 머지 결과 |
# |-|-|--------|
# | 유지 | 유지 | 유지 |
# | 삭제 | 유지 | 제거 |
# | 유지 | 삭제 | 제거 |
# | 삭제 | 삭제 | 제거 |

# %% [markdown]
# ## 실습 3: 파일이 삭제되는 경우

# %% [markdown]
# - 레포지토리 생성

# %%
# | output: false
cd $HOME/lab
rm -rf test_merge_03
git init test_merge_03
cd test_merge_03
# Out:
# Initialized empty Git repository in /Users/joelkim/Work/personal/book_git/lab/test_merge_03/.git/

# %% [markdown]
# :::{.cell}
# ::::{.cell-output .cell-output-stdout}
# Initialized empty Git repository in ~/lab/test_merge_03/.git/
# ::::
# :::

# %% [markdown]
# - 3개의 파일 생성

# %%
echo "file1 line 1" > file1.txt
echo "file2 line 1" > file2.txt
echo "file3 line 1" > file3.txt
git add .
git commit -m "c1"
# Out:
# [main (root-commit) d8a249f] c1
#  3 files changed, 3 insertions(+)
#  create mode 100644 file1.txt
#  create mode 100644 file2.txt
#  create mode 100644 file3.txt

# %% [markdown]
# - branch A 생성

# %%
git branch A

# %% [markdown]
# - 브랜치 A로 전환

# %%
git switch A
# Out:
# Switched to branch 'A'

# %% [markdown]
# - file2.txt 삭제

# %%
git rm file2.txt
git commit -m "c2"
# Out:
# rm 'file2.txt'
# [A f846ef2] c2
#  1 file changed, 1 deletion(-)
#  delete mode 100644 file2.txt

# %% [markdown]
# - main 브랜치로 전환

# %%
git switch main
# Out:
# Switched to branch 'main'

# %% [markdown]
# - file3.txt 삭제

# %%
git rm file3.txt
git commit -m "c3"
# Out:
# rm 'file3.txt'
# [main 2d09372] c3
#  1 file changed, 1 deletion(-)
#  delete mode 100644 file3.txt

# %% [markdown]
# - 현재 브랜치 상태

# %%
git log --oneline --graph --all --decorate
# Out:
# * f846ef2 (A) c2
# | * 2d09372 (HEAD -> main) c3
# |/
# * d8a249f c1

# %% [markdown]
# - main 브랜치에서 A 브랜치 머지

# %%
git merge A -m "c4"
# Out:
# Merge made by the 'ort' strategy.
#  file2.txt | 1 -
#  1 file changed, 1 deletion(-)
#  delete mode 100644 file2.txt

# %% [markdown]
# - main 브랜치에는 c4 라는 머지 커밋이 생성
# - A 브랜치는 그대로 변화없음

# %%
git log --oneline --graph --all --decorate
# Out:
# *   10135c4 (HEAD -> main) c4
# |\
# | * f846ef2 (A) c2
# * | 2d09372 c3
# |/
# * d8a249f c1

# %% [markdown]
# - 양쪽 브랜치에서 삭제한 파일들이 모두 제거됨

# %%
ls
# Out:
# file1.txt
